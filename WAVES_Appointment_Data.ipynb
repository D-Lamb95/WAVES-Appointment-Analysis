# %% [markdown]
# Derek Lamb
# DSC 640
# Weeks 3& 4 Assingment

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import calendar 

# File paths
file_paths = [
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.01_WAVES-ACCESS-RECORDS.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.02_WAVES-ACCESS-RECORDS.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.03_WAVES-ACCESS-RECORDS.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.04_WAVES-ACCESS-RECORDS.csv'
]

# Load and combine datasets
dataframes = [pd.read_csv(file, low_memory=False) for file in file_paths]
combined_df = pd.concat(dataframes, ignore_index=True)

# Cleaning mixed data types and missing values
# Convert numeric columns with mixed types to float
numeric_columns = ['BDGNBR', 'POA', 'POD']  # Update based on your dataset
for col in numeric_columns:
    combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')

# Standardize date columns
date_columns = ['TOA', 'Release Date']  # Update with the correct date column names
for col in date_columns:
    combined_df[col] = pd.to_datetime(combined_df[col], errors='coerce')

# %%
# Fill missing values
combined_df['Meeting Room'] = combined_df['Meeting Room'].fillna('Unknown')  # Example for categorical data
combined_df['BDGNBR'] = combined_df['BDGNBR'].fillna(combined_df['BDGNBR'].median())  # Example for numeric data

# Save the cleaned dataset
cleaned_file_path = '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023First4.csv'
combined_df.to_csv(cleaned_file_path, index=False)

# Display the first few rows of the cleaned dataset
print(combined_df.head())

print(f"Cleaned dataset saved to: {cleaned_file_path}")
# Out:
#   Last Name First Name Middle Initial     UIN    BDGNBR Access Type  \
# 0     AABYE       MARY              A  U13230  197546.0          VA
# 1     AALST      CARLO              B  U10746  200479.0          VA
# 2  AARONSON      SCOTT              I  U21068  201034.0          VA
# 3      ABAD       JOHN              C  U11018  200479.0          VA
# 4    ABADIE     NATHAN              D  U15945  200479.0          VA
#
#                   TOA  POA  TOD  POD  ... Visitee Last Name  \
# 0 2023-01-19 08:58:00  NaN  NaN  NaN  ...           Epstein
# 1 2023-01-03 09:37:00  NaN  NaN  NaN  ...            Office
# 2 2023-01-31 10:42:00  NaN  NaN  NaN  ...         Durkovich
# 3                 NaT  NaN  NaN  NaN  ...            Office
# 4 2023-01-21 09:46:00  NaN  NaN  NaN  ...            Office
#
#   Visitee First Name Meeting Location         Meeting Room  Caller Last Name  \
# 0              Diana             OEOB  Bowling Alley - 037           EPSTEIN
# ...

# %%
# File paths for the second set of files
file_paths = [
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.05_WAVES-ACCESS-RECORDS.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.06_WAVES-ACCESS-RECORDS.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.07_WAVES-ACCESS-RECORDS.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.08_WAVES-ACCESS-RECORDS.csv'
]

# Load and combine datasets
dataframes = [pd.read_csv(file, low_memory=False) for file in file_paths]
combined_df = pd.concat(dataframes, ignore_index=True)

# Cleaning mixed data types and missing values
# Convert numeric columns with mixed types to float
numeric_columns = ['BDGNBR', 'POA', 'POD']  # Update based on your dataset
for col in numeric_columns:
    combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')

# Standardize date columns
date_columns = ['TOA', 'Release Date']  # Update with the correct date column names
for col in date_columns:
    combined_df[col] = pd.to_datetime(combined_df[col], errors='coerce')

#F ill missing values
combined_df['Meeting Room'] = combined_df['Meeting Room'].fillna('Unknown')  # Example for categorical data
combined_df['BDGNBR'] = combined_df['BDGNBR'].fillna(combined_df['BDGNBR'].median())  # Example for numeric data

# Save the cleaned dataset
cleaned_file_path = '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023Mid4.csv'
combined_df.to_csv(cleaned_file_path, index=False)

# Display the first few rows of the cleaned dataset
print(combined_df.head())

print(f"Cleaned dataset saved to: {cleaned_file_path}")
# Out:
#        Last Name     First Name Middle Initial     UIN    BDGNBR Access Type  \
# 0              A         ABSENT              A  U66801  201384.0          VA
# 1  AABERGSOMOGYI        MARTINA              S  U73638  201384.0          VA
# 2  AABERGSOMOGYI  MARTINASOPHIE              N  U76081  201384.0          VA
# 3  AABERGSOMOGYI  MARTINASOPHIE              N  U77506  197647.0          VA
# 4        AALIYAH       LAWRENCE              N  U66140  201384.0          VA
#
#                   TOA  POA  TOD  POD  ...  Last Entry Date Terminal Suffix  \
# 0                 NaT  NaN  NaN  NaN  ...   5/4/2023 10:42              VW
# 1                 NaT  NaN  NaN  NaN  ...   5/16/2023 7:47              VW
# 2                 NaT  NaN  NaN  NaN  ...  5/19/2023 16:14              AR
# 3 2023-05-22 09:44:00  NaN  NaN  NaN  ...   5/22/2023 6:32              AR
# 4                 NaT  NaN  NaN  NaN  ...   5/3/2023 10:59              VW
#
# ...

# %%
# File paths for the third set of files
file_paths = [
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.09_WAVES-ACCESS-RECORDS.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.10_WAVES-ACCESS-RECORDS.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.11_WAVES-ACCESS-RECORDS.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023.12_WAVES-ACCESS-RECORDS.csv'
]

# Load and combine datasets
dataframes = [pd.read_csv(file, low_memory=False) for file in file_paths]
combined_df = pd.concat(dataframes, ignore_index=True)

# Cleaning mixed data types and missing values
# Convert numeric columns with mixed types to float
numeric_columns = ['BDGNBR', 'POA', 'POD']  # Update based on your dataset
for col in numeric_columns:
    combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')

# Standardize date columns
date_columns = ['TOA', 'Release Date']  # Update with the correct date column names
for col in date_columns:
    combined_df[col] = pd.to_datetime(combined_df[col], errors='coerce')

# Fill missing values
combined_df['Meeting Room'] = combined_df['Meeting Room'].fillna('Unknown')  # Example for categorical data
combined_df['BDGNBR'] = combined_df['BDGNBR'].fillna(combined_df['BDGNBR'].median())  # Example for numeric data

# Save the cleaned dataset
cleaned_file_path = '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023Last4.csv'
combined_df.to_csv(cleaned_file_path, index=False)

# Display the first few rows of the cleaned dataset
print(combined_df.head())

print(f"Cleaned dataset saved to: {cleaned_file_path}")
# Out:
# /var/folders/7d/y0dq6pts3c5c4tx5d99hqkch0000gn/T/ipykernel_31033/1491754169.py:22: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   combined_df[col] = pd.to_datetime(combined_df[col], errors='coerce')
#   Last Name   First Name Middle Initial     UIN    BDGNBR Access Type  \
# 0      AABY    KATHERINE              N  U42563  198692.0          VA
# 1   AADLAND         JACK              L  U43753  202670.0          VA
# 2   AADLAND         JILL              M  U43753  202670.0          VA
# 3   AARDAHL  CHRISTOPHER              L  U34849  205268.0          VA
# 4     AARON       THOMAS              J  U39433  202670.0          VA
#
#                   TOA  POA  TOD  POD  ...  Last Entry Date Terminal Suffix  \
# 0 2023-09-15 13:42:00  NaN  NaN  NaN  ...  9/13/2023 14:02              AT
# ...

# %%
# File paths for the cleaned data
file_paths = [
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023First4.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023Mid4.csv',
    '/Users/dereklamb/Downloads/Weeks3&4Exercise/2023Last4.csv'
]

# Load and combine datasets
dataframes = [pd.read_csv(file, low_memory=False) for file in file_paths]
combined_df = pd.concat(dataframes, ignore_index=True)

# Cleaning mixed data types and missing values
# Example 1: Convert numeric columns with mixed types to float
numeric_columns = ['BDGNBR', 'POA', 'POD']  # Update based on your dataset
for col in numeric_columns:
    combined_df[col] = pd.to_numeric(combined_df[col], errors='coerce')

# Example 2: Standardize date columns
date_columns = ['TOA', 'Release Date']  # Update with the correct date column names
for col in date_columns:
    combined_df[col] = pd.to_datetime(combined_df[col], errors='coerce')

# Example 3: Fill missing values
combined_df['Meeting Room'] = combined_df['Meeting Room'].fillna('Unknown')  # Example for categorical data
combined_df['BDGNBR'] = combined_df['BDGNBR'].fillna(combined_df['BDGNBR'].median())  # Example for numeric data

# Save the cleaned dataset
cleaned_file_path = '/Users/dereklamb/Downloads/Weeks3&4Exercise/Cleaned_WAVES_Access_Records_All.csv'
combined_df.to_csv(cleaned_file_path, index=False)

# Display the first few rows of the cleaned dataset
print(combined_df.head())

print(f"Cleaned dataset saved to: {cleaned_file_path}")

# Extract records for June to August
missing_data_check = valid_data[
    (valid_data['TOA'] >= '2023-06-01') & 
    (valid_data['TOA'] <= '2023-08-31')
]

print(missing_data_check)
# Out:
#   Last Name First Name Middle Initial     UIN    BDGNBR Access Type  \
# 0     AABYE       MARY              A  U13230  197546.0          VA
# 1     AALST      CARLO              B  U10746  200479.0          VA
# 2  AARONSON      SCOTT              I  U21068  201034.0          VA
# 3      ABAD       JOHN              C  U11018  200479.0          VA
# 4    ABADIE     NATHAN              D  U15945  200479.0          VA
#
#                   TOA  POA  TOD  POD  ... Visitee Last Name  \
# 0 2023-01-19 08:58:00  NaN  NaN  NaN  ...           Epstein
# 1 2023-01-03 09:37:00  NaN  NaN  NaN  ...            Office
# 2 2023-01-31 10:42:00  NaN  NaN  NaN  ...         Durkovich
# 3                 NaT  NaN  NaN  NaN  ...            Office
# 4 2023-01-21 09:46:00  NaN  NaN  NaN  ...            Office
#
#   Visitee First Name Meeting Location         Meeting Room  Caller Last Name  \
# 0              Diana             OEOB  Bowling Alley - 037           EPSTEIN
# ...

# %%
combined_df['TOA'] = pd.to_datetime(combined_df['TOA'], errors='coerce')

print(combined_df[combined_df['TOA'].isna()])

filtered_data = combined_df[(combined_df['TOA'] >= '2023-06-01') & (combined_df['TOA'] <= '2023-08-31')]
print(filtered_data)

# Ensure TOA is in datetime format
combined_df['TOA'] = pd.to_datetime(combined_df['TOA'], errors='coerce')

# Extract the month from TOA
combined_df['Month'] = combined_df['TOA'].dt.month

print(combined_df.columns)
# Out:
#         Last Name   First Name Middle Initial     UIN    BDGNBR Access Type  \
# 3            ABAD         JOHN              C  U11018  200479.0          VA
# 6         ABADULA       LAMROT              N  U19471  200479.0          VA
# 12        ABAZEED          ALI              E  U15184  200479.0          VA
# 18         ABBASI        ABDUL              G  U17396  200479.0          VA
# 29          ABBOT      CHARLES              S  U17797  200479.0          VA
# ...           ...          ...            ...     ...       ...         ...
# 843197  YADLAPATI        VIJAY              N  U00129  202670.0          VA
# 843206     PARISH    CHARMAINE              J  U02030  202670.0          VA
# 843211     PARISH    CHARMAINE              J  U02031  202670.0          VA
# 843214  KALOGERAS      MATTHEW              T  U03542  202670.0          VA
# 843215    JUNKINS  CHRISTOPHER              A  U02588  202670.0          VA
#
# ...

# %%
# Group by month and count visitors
monthly_visitors = combined_df.groupby('Month').size()

# Plot the bar chart
plt.figure(figsize=(10, 6))
monthly_visitors.plot(kind='bar', edgecolor='black')
plt.title("Monthly Visitor Counts in 2023")
plt.xlabel("Month")
plt.ylabel("Number of Visitors")
plt.xticks(ticks=range(len(monthly_visitors.index)), labels=monthly_visitors.index, rotation=45)
plt.tight_layout()
plt.show()

# %%
# Ensure TOA is in datetime format
combined_df['TOA'] = pd.to_datetime(combined_df['TOA'], errors='coerce')

# Extract the week number from TOA
combined_df['Week'] = combined_df['TOA'].dt.isocalendar().week

print(combined_df.columns)
# Out:
# Index(['Last Name', 'First Name', 'Middle Initial', 'UIN', 'BDGNBR',
#        'Access Type', 'TOA', 'POA', 'TOD', 'POD', 'Appointment Made Date',
#        'Appointment Start Date', 'Appointment End Date',
#        'Appointment Cancel Date', 'Total People', 'Last Updated By', 'POST',
#        'Last Entry Date', 'Terminal Suffix', 'Visitee Last Name',
#        'Visitee First Name', 'Meeting Location', 'Meeting Room',
#        'Caller Last Name', 'Caller First Name', 'CALLER_ROOM', 'RELEASEDATE',
#        'Caller Room', 'Release Date', 'Month', 'Week'],
#       dtype='object')

# %%
# Group by week and meeting location for stacked bar chart
weekly_visitors = combined_df.groupby(['Week', 'Meeting Location']).size().unstack(fill_value=0)

# Plot the stacked bar chart
weekly_visitors.plot(kind='bar', stacked=True, figsize=(14, 8), edgecolor='black')
plt.title("Weekly Visitor Counts by Meeting Location in 2023")
plt.xlabel("Week Number")
plt.ylabel("Number of Visitors")
plt.legend(title="Meeting Location", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.tight_layout()
plt.show()

# %%
# Use 'Total_People' as the number of attendees
valid_data['Attendees'] = valid_data['Total People']

print(combined_df[
    (combined_df['TOA'] >= '2023-06-01') & 
    (combined_df['TOA'] <= '2023-08-31')
])
# Out:
# Empty DataFrame
# Columns: [Last Name, First Name, Middle Initial, UIN, BDGNBR, Access Type, TOA, POA, TOD, POD, Appointment Made Date, Appointment Start Date, Appointment End Date, Appointment Cancel Date, Total People, Last Updated By, POST, Last Entry Date, Terminal Suffix, Visitee Last Name, Visitee First Name, Meeting Location, Meeting Room, Caller Last Name, Caller First Name, CALLER_ROOM, RELEASEDATE, Caller Room, Release Date, Month, Week, Attendees]
# Index: []
#
# [0 rows x 32 columns]

# %%
# Assign 'Total People' to 'Attendees'
combined_df['Attendees'] = combined_df['Total People']

plt.figure(figsize=(12, 6))
plt.scatter(combined_df['TOA'], combined_df['Attendees'], alpha=0.5, s=10, label='Attendees')
plt.title("Number of Attendees in Visits Over Time (2023)")
plt.xlabel("Date")
plt.ylabel("Number of Attendees")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Group by week and count visitors
weekly_trends = combined_df.groupby('Week').size()

# Plot the line chart
plt.figure(figsize=(12, 6))
weekly_trends.plot(kind='line', marker='o')
plt.title("Weekly Visitor Trends in 2023")
plt.xlabel("Week Number")
plt.ylabel("Number of Visitors")
plt.grid(True, linestyle='--', alpha=0.6)
plt.tight_layout()
plt.show()

# %%
# Group by access type and count
access_type_counts = combined_df['Access Type'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
access_type_counts.plot(kind='pie', autopct='%1.1f%%', startangle=90, legend=True)
plt.title("Proportion of Visitors by Access Type")
plt.ylabel("")  # Hide y-label for aesthetics
plt.show()

# %%
# Extract day of the week and hour
combined_df['Day of Week'] = combined_df['TOA'].dt.day_name()
combined_df['Hour'] = combined_df['TOA'].dt.hour

# Group by day of the week and hour
heatmap_data = combined_df.groupby(['Day of Week', 'Hour']).size().unstack(fill_value=0)

# Sort days of the week in order
days_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
heatmap_data = heatmap_data.reindex(days_order)

# Plot the heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(heatmap_data, cmap="Blues", annot=False, fmt='d')
plt.title("Hourly Visitor Density by Day of the Week")
plt.xlabel("Hour")
plt.ylabel("Day of the Week")
plt.tight_layout()
plt.show()
